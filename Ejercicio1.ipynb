# %%
'''Debes crear un programa en Python que:
Cree un diccionario donde:,
o    la clave sea el nombre del vendedor
o    el valor sea el total vendido por ese vendedor
Determine:,
o    qué vendedor vendió más dinero
Muestre por pantalla:,
o    el total vendido por cada vendedor
o    el vendedor con mayor venta
Restricciones:
•    Usa listas, tuplas y diccionarios
•    Usa for y if
•    No usar librerías externas
•    No usar funciones avanzadas (max, sum, etc.)'''

ventas = [
    ("ana", 120),
    ("juan", 90),
    ("ana", 150),
    ("juan", 150),
    ("ana", 80),
    ("juan", 200),
    ("ana", 200),
    ("juan", 50),
    ("ana", 100)
]

diccionario = {}
